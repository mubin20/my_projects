# %%
import tpot
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %%
from tpot import TPOTRegressor
from sklearn.model_selection import RepeatedKFold
import pandas as pd

# %%
ipl_data = pd.read_csv("../Datasets/eda_feature_engineering.csv")

# %%
# Note that batting team and bowling team have same values
# Choosing consistent playing teams

ipl_teams = ['Kolkata Knight Riders', 'Royal Challengers Bangalore',
       'Chennai Super Kings', 'Punjab Kings', 'Rajasthan Royals',
       'Mumbai Indians','Sunrisers Hyderabad','Delhi Capitals']

# Delhi Daredevils name was changed to Delhi Capitals
# Kings XI Punjab name was changed to  Punjab Kings

# let's rename this teams with current name

ipl_data.replace({"Delhi Daredevils": "Delhi Capitals", "Kings XI Punjab": "Punjab Kings"}, inplace=True)

# %%
# Drop team values of unselected teams
non_ipl_teams = list(filter(lambda x: x not in ipl_teams, ipl_data.batting_team.unique()))

# %%
# Dropping non_ipl_teams

for i in non_ipl_teams:
    ipl_data.drop(ipl_data.loc[(ipl_data.batting_team == i) | (ipl_data.bowling_team == i)].index, axis=0, inplace=True)
    
ipl_data = ipl_data.reset_index(drop=True)

# %%
# Will drop the first five over to get better consistent score result.
ipl_data = ipl_data.loc[ipl_data.over >= 5]
ipl_data.head(20)
# Out:
#         id  inning  over  ball  total_runs  is_wicket           batting_team  \
# 32  335982       1   5.1    33           1          0  Kolkata Knight Riders
# 33  335982       1   5.2    34           0          1  Kolkata Knight Riders
# 34  335982       1   5.3    35           0          0  Kolkata Knight Riders
# 35  335982       1   5.4    36           0          0  Kolkata Knight Riders
# 36  335982       1   5.5    37           0          0  Kolkata Knight Riders
# 37  335982       1   5.6    38           0          0  Kolkata Knight Riders
# 38  335982       1   6.1    39           1          0  Kolkata Knight Riders
# 39  335982       1   6.2    40           1          0  Kolkata Knight Riders
# 40  335982       1   6.3    41           1          0  Kolkata Knight Riders
# 41  335982       1   6.4    42           2          0  Kolkata Knight Riders
# 42  335982       1   6.5    43           1          0  Kolkata Knight Riders
# 43  335982       1   6.6    44           1          0  Kolkata Knight Riders
# 44  335982       1   7.1    45           0          0  Kolkata Knight Riders
# 45  335982       1   7.2    46           1          0  Kolkata Knight Riders
# 46  335982       1   7.3    47           1          0  Kolkata Knight Riders
# 47  335982       1   7.4    48           1          0  Kolkata Knight Riders
# 48  335982       1   7.5    49           1          0  Kolkata Knight Riders
# 49  335982       1   7.6    50           1          0  Kolkata Knight Riders
# 50  335982       1   8.1    51           0          0  Kolkata Knight Riders
# 51  335982       1   8.2    52           0          0  Kolkata Knight Riders
#
#                    bowling_team  final_score  wickets  runs  \
# 32  Royal Challengers Bangalore          222        0    61
# 33  Royal Challengers Bangalore          222        1    61
# 34  Royal Challengers Bangalore          222        1    61
# 35  Royal Challengers Bangalore          222        1    61
# 36  Royal Challengers Bangalore          222        1    61
# 37  Royal Challengers Bangalore          222        1    61
# 38  Royal Challengers Bangalore          222        1    62
# 39  Royal Challengers Bangalore          222        1    63
# 40  Royal Challengers Bangalore          222        1    64
# 41  Royal Challengers Bangalore          222        1    66
# 42  Royal Challengers Bangalore          222        1    67
# 43  Royal Challengers Bangalore          222        1    68
# 44  Royal Challengers Bangalore          222        1    68
# 45  Royal Challengers Bangalore          222        1    69
# 46  Royal Challengers Bangalore          222        1    70
# 47  Royal Challengers Bangalore          222        1    71
# 48  Royal Challengers Bangalore          222        1    72
# 49  Royal Challengers Bangalore          222        1    73
# 50  Royal Challengers Bangalore          222        1    73
# 51  Royal Challengers Bangalore          222        1    73
#
#     last_5_over_wickets  last_5_over_runs  last_5_over_balls  \
# 32                    0                60                 32
# 33                    1                60                 33
# 34                    1                60                 34
# 35                    1                60                 35
# 36                    1                60                 36
# 37                    1                60                 37
# 38                    1                61                 38
# 39                    1                62                 39
# 40                    1                63                 40
# 41                    1                65                 41
# 42                    1                66                 42
# 43                    1                67                 43
# 44                    1                67                 44
# 45                    1                68                 45
# 46                    1                69                 46
# 47                    1                70                 47
# 48                    1                71                 48
# 49                    1                72                 49
# 50                    1                72                 50
# 51                    1                72                 51
#
#                     venue                 winner
# 32  M Chinnaswamy Stadium  Kolkata Knight Riders
# 33  M Chinnaswamy Stadium  Kolkata Knight Riders
# 34  M Chinnaswamy Stadium  Kolkata Knight Riders
# 35  M Chinnaswamy Stadium  Kolkata Knight Riders
# 36  M Chinnaswamy Stadium  Kolkata Knight Riders
# 37  M Chinnaswamy Stadium  Kolkata Knight Riders
# 38  M Chinnaswamy Stadium  Kolkata Knight Riders
# 39  M Chinnaswamy Stadium  Kolkata Knight Riders
# 40  M Chinnaswamy Stadium  Kolkata Knight Riders
# 41  M Chinnaswamy Stadium  Kolkata Knight Riders
# 42  M Chinnaswamy Stadium  Kolkata Knight Riders
# 43  M Chinnaswamy Stadium  Kolkata Knight Riders
# 44  M Chinnaswamy Stadium  Kolkata Knight Riders
# 45  M Chinnaswamy Stadium  Kolkata Knight Riders
# 46  M Chinnaswamy Stadium  Kolkata Knight Riders
# 47  M Chinnaswamy Stadium  Kolkata Knight Riders
# 48  M Chinnaswamy Stadium  Kolkata Knight Riders
# 49  M Chinnaswamy Stadium  Kolkata Knight Riders
# 50  M Chinnaswamy Stadium  Kolkata Knight Riders
# 51  M Chinnaswamy Stadium  Kolkata Knight Riders

# %%
# Will numer the team as per the winning counts Mumbai being the highest as 7 and 0 Sunrisers being lowest winning count.

encoded_teams = {k:v for v, k in enumerate(ipl_data.winner.value_counts().sort_values().index, 0)}
encoded_teams
# Out:
# {'Sunrisers Hyderabad': 0,
#  'Delhi Capitals': 1,
#  'Rajasthan Royals': 2,
#  'Royal Challengers Bangalore': 3,
#  'Punjab Kings': 4,
#  'Kolkata Knight Riders': 5,
#  'Chennai Super Kings': 6,
#  'Mumbai Indians': 7}

# %%
# Mapping encoded values to new data frame

ipl_data.batting_team = ipl_data.batting_team.map(encoded_teams)
ipl_data.bowling_team = ipl_data.bowling_team.map(encoded_teams)

# %%
# One hot encoding of venue column

encoded_venue = pd.get_dummies(ipl_data.venue, drop_first=True)

# 0 being Barbati Stadium when performing get_dummies 

encoded_venue.head()
# Out:
#     Brabourne Stadium  Buffalo Park  De Beers Diamond Oval  \
# 32                  0             0                      0
# 33                  0             0                      0
# 34                  0             0                      0
# 35                  0             0                      0
# 36                  0             0                      0
#
#     Dr DY Patil Sports Academy  \
# 32                           0
# 33                           0
# 34                           0
# 35                           0
# 36                           0
#
#     Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  \
# 32                                                  0
# 33                                                  0
# 34                                                  0
# 35                                                  0
# 36                                                  0
#
#     Dubai International Cricket Stadium  Eden Gardens  Feroz Shah Kotla  \
# 32                                    0             0                 0
# 33                                    0             0                 0
# 34                                    0             0                 0
# 35                                    0             0                 0
# 36                                    0             0                 0
#
#     Himachal Pradesh Cricket Association Stadium  Holkar Cricket Stadium  ...  \
# 32                                             0                       0  ...
# 33                                             0                       0  ...
# 34                                             0                       0  ...
# 35                                             0                       0  ...
# 36                                             0                       0  ...
#
#     Rajiv Gandhi International Stadium, Uppal  Sardar Patel Stadium, Motera  \
# 32                                          0                             0
# 33                                          0                             0
# 34                                          0                             0
# 35                                          0                             0
# 36                                          0                             0
#
#     Sawai Mansingh Stadium  Shaheed Veer Narayan Singh International Stadium  \
# 32                       0                                                 0
# 33                       0                                                 0
# 34                       0                                                 0
# 35                       0                                                 0
# 36                       0                                                 0
#
#     Sharjah Cricket Stadium  Sheikh Zayed Stadium  St George's Park  \
# 32                        0                     0                 0
# 33                        0                     0                 0
# 34                        0                     0                 0
# 35                        0                     0                 0
# 36                        0                     0                 0
#
#     Subrata Roy Sahara Stadium  SuperSport Park  Wankhede Stadium
# 32                           0                0                 0
# 33                           0                0                 0
# 34                           0                0                 0
# 35                           0                0                 0
# 36                           0                0                 0
#
# [5 rows x 29 columns]

# %%
# over, batting_team, bowling_team, wickets, runs, last_5_over_wickets, last_5_over_runs, last_5_over_balls,venue.
# final_score is our target variable

ipl_data = ipl_data[["over", "wickets","runs", "last_5_over_wickets", "last_5_over_runs","batting_team", "bowling_team", "final_score"]]
ipl_data.head()
# Out:
#     over  wickets  runs  last_5_over_wickets  last_5_over_runs  batting_team  \
# 32   5.1        0    61                    0                60             5
# 33   5.2        1    61                    1                60             5
# 34   5.3        1    61                    1                60             5
# 35   5.4        1    61                    1                60             5
# 36   5.5        1    61                    1                60             5
#
#     bowling_team  final_score
# 32             3          222
# 33             3          222
# 34             3          222
# 35             3          222
# 36             3          222

# %%
ipl_data = pd.concat([ipl_data, encoded_venue], axis=1).copy()
ipl_data.head()
# Out:
#     over  wickets  runs  last_5_over_wickets  last_5_over_runs  batting_team  \
# 32   5.1        0    61                    0                60             5
# 33   5.2        1    61                    1                60             5
# 34   5.3        1    61                    1                60             5
# 35   5.4        1    61                    1                60             5
# 36   5.5        1    61                    1                60             5
#
#     bowling_team  final_score  Brabourne Stadium  Buffalo Park  ...  \
# 32             3          222                  0             0  ...
# 33             3          222                  0             0  ...
# 34             3          222                  0             0  ...
# 35             3          222                  0             0  ...
# 36             3          222                  0             0  ...
#
#     Rajiv Gandhi International Stadium, Uppal  Sardar Patel Stadium, Motera  \
# 32                                          0                             0
# 33                                          0                             0
# 34                                          0                             0
# 35                                          0                             0
# 36                                          0                             0
#
#     Sawai Mansingh Stadium  Shaheed Veer Narayan Singh International Stadium  \
# 32                       0                                                 0
# 33                       0                                                 0
# 34                       0                                                 0
# 35                       0                                                 0
# 36                       0                                                 0
#
#     Sharjah Cricket Stadium  Sheikh Zayed Stadium  St George's Park  \
# 32                        0                     0                 0
# 33                        0                     0                 0
# 34                        0                     0                 0
# 35                        0                     0                 0
# 36                        0                     0                 0
#
#     Subrata Roy Sahara Stadium  SuperSport Park  Wankhede Stadium
# 32                           0                0                 0
# 33                           0                0                 0
# 34                           0                0                 0
# 35                           0                0                 0
# 36                           0                0                 0
#
# [5 rows x 37 columns]

# %%
# X is the feature matrix and y being the target variable

X = ipl_data.drop(columns="final_score") 
y = ipl_data.final_score

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

(X_train.shape, y_train.shape), (X_test.shape, y_test.shape)
# Out:
# (((88046, 36), (88046,)), ((22012, 36), (22012,)))

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
